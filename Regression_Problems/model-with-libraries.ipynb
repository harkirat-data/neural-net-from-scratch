# %%
from sklearn.datasets import make_regression
import numpy as np
import pandas as pd

# %%
X, y = make_regression(n_samples=75, n_features=2, noise=10, random_state=42)

cgpa = 4 + (X[:, 0] - X[:, 0].min()) / (X[:, 0].max() - X[:, 0].min()) * 6
profile_score = 40 + (X[:, 1] - X[:, 1].min()) / (X[:, 1].max() - X[:, 1].min()) * 60
lpa = 1 + (y - y.min()) / (y.max() - y.min()) * 9

# %%
df = pd.DataFrame({'cgpa': cgpa, 'profile_score': profile_score, 'lpa': lpa})

df['cgpa'] = (df['cgpa'] - df['cgpa'].mean()) / df['cgpa'].std()
df['profile_score'] = (df['profile_score'] - df['profile_score'].mean()) / df['profile_score'].std()

df
# Out:
#         cgpa  profile_score       lpa
# 0   0.534185      -0.432249  4.971321
# 1  -0.545939      -1.778404  1.245881
# 2  -0.549966      -0.951240  2.651913
# 3   1.563308       0.571495  8.538477
# 4   0.190834       0.996206  6.976188
# ..       ...            ...       ...
# 70 -0.448971      -0.357525  3.756792
# 71  1.575257      -0.871144  6.165574
# 72  0.563602      -0.364347  5.721305
# 73  0.773865       1.451648  8.967541
# 74  0.424505      -0.017222  5.381901
#
# [75 rows x 3 columns]

# %%
import tensorflow
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(2,activation = 'linear', input_dim = 2))
model.add(Dense(1,activation = 'linear'))
# Out:
# C:\Users\PC\AppData\Roaming\Python\Python313\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 2)              │             6 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             3 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9 (36.00 B)
#  Trainable params: 9 (36.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.get_weights()
# Out:
# [array([[ 0.05450094, -0.68936956],
#         [ 0.07587636, -0.66151434]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[-0.06688702],
#         [ 0.577924  ]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
new_weights = [np.array([[0.1,0.1], [0.1 , 0.1]], dtype = np.float32),
               np.array([0.,0.],dtype = np.float32),
               np.array([[0.1],[0.1]],dtype = np.float32),
               np.array([0.], dtype = np.float32)]

# %%
model.set_weights(new_weights)

# %%
model.get_weights()
# Out:
# [array([[0.1, 0.1],
#         [0.1, 0.1]], dtype=float32),
#  array([0., 0.], dtype=float32),
#  array([[0.1],
#         [0.1]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
optimizer = keras.optimizers.Adam(learning_rate = 0.001)
model.compile(loss = 'mean_squared_error', optimizer = optimizer)

# %%
model.fit(df.iloc[:,0:-1].values,df['lpa'].values,epochs = 75 , verbose = 1, batch_size = 1)
# Out:
# Epoch 1/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 30.5272
# Epoch 2/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - loss: 29.4557
# Epoch 3/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - loss: 28.1344
# Epoch 4/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step - loss: 26.5188
# Epoch 5/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - loss: 24.6174
# Epoch 6/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - loss: 22.4476
# Epoch 7/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - loss: 20.1153
# Epoch 8/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - loss: 17.6527
# Epoch 9/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step - loss: 15.1959
# Epoch 10/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - loss: 12.7561
# Epoch 11/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 10.5103
# Epoch 12/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - loss: 8.4229
# Epoch 13/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - loss: 6.5655
# Epoch 14/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9822
# Epoch 15/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - loss: 3.6777
# Epoch 16/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - loss: 2.6202
# Epoch 17/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step - loss: 1.8105
# Epoch 18/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - loss: 1.2152
# Epoch 19/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - loss: 0.7885
# Epoch 20/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5012
# Epoch 21/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - loss: 0.3158
# Epoch 22/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - loss: 0.1999
# Epoch 23/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step - loss: 0.1313
# Epoch 24/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - loss: 0.0921
# Epoch 25/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 984us/step - loss: 0.0707
# Epoch 26/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - loss: 0.0590
# Epoch 27/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - loss: 0.0529
# Epoch 28/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step - loss: 0.0497
# Epoch 29/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step - loss: 0.0483
# Epoch 30/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - loss: 0.0476
# Epoch 31/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - loss: 0.0471
# Epoch 32/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0469
# Epoch 33/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - loss: 0.0467
# Epoch 34/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - loss: 0.0466
# Epoch 35/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - loss: 0.0465
# Epoch 36/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step - loss: 0.0468
# Epoch 37/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step - loss: 0.0467
# Epoch 38/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - loss: 0.0466
# Epoch 39/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - loss: 0.0466
# Epoch 40/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - loss: 0.0465
# Epoch 41/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0466
# Epoch 42/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - loss: 0.0466
# Epoch 43/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - loss: 0.0467
# Epoch 44/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - loss: 0.0470
# Epoch 45/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - loss: 0.0469
# Epoch 46/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - loss: 0.0466
# Epoch 47/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - loss: 0.0468
# Epoch 48/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - loss: 0.0468
# Epoch 49/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - loss: 0.0469
# Epoch 50/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - loss: 0.0468
# Epoch 51/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - loss: 0.0475
# Epoch 52/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step - loss: 0.0468
# Epoch 53/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step - loss: 0.0470
# Epoch 54/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - loss: 0.0474
# Epoch 55/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - loss: 0.0470
# Epoch 56/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - loss: 0.0471
# Epoch 57/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - loss: 0.0469
# Epoch 58/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - loss: 0.0473
# Epoch 59/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - loss: 0.0474
# Epoch 60/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0471
# Epoch 61/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - loss: 0.0473
# Epoch 62/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 0.0473
# Epoch 63/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - loss: 0.0471
# Epoch 64/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - loss: 0.0474
# Epoch 65/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - loss: 0.0471
# Epoch 66/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - loss: 0.0476
# Epoch 67/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - loss: 0.0469
# Epoch 68/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step - loss: 0.0471
# Epoch 69/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step - loss: 0.0468
# Epoch 70/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - loss: 0.0475
# Epoch 71/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step - loss: 0.0473
# Epoch 72/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step - loss: 0.0473
# Epoch 73/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step - loss: 0.0471
# Epoch 74/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step - loss: 0.0471
# Epoch 75/75
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step - loss: 0.0477

# %%
model.get_weights()
# Out:
# [array([[0.6355275 , 0.6355275 ],
#         [0.63998026, 0.63998026]], dtype=float32),
#  array([1.5538393, 1.5538393], dtype=float32),
#  array([[1.3067946],
#         [1.3067946]], dtype=float32),
#  array([0.966463], dtype=float32)]
